# %% [markdown]
# # Execution Statistics
#
# This table contains the latest execution statistics.
#
# ```{nb-exec-table}
# ```
#
# (status:machine-details)=
#
# These lectures are built on `linux` instances through `github actions`.
#
# These lectures are using the following python version

# %%
# !python --version
# Out:
# Python 3.10.13

# %% [markdown]
# and the following package versions

# %%
# !conda list
# Out:
# # packages in environment at /Users/carlosmendez/miniforge3:
# #
# # Name                    Version                   Build  Channel
# absl-py                   2.4.0                    pypi_0    pypi
# affine                    2.4.0                    pypi_0    pypi
# altair                    5.5.0                    pypi_0    pypi
# anyio                     4.12.1             pyhcf101f3_0    conda-forge
# appnope                   0.1.4              pyhd8ed1ab_1    conda-forge
# archspec                  0.2.2              pyhd8ed1ab_0    conda-forge
# argon2-cffi               25.1.0             pyhd8ed1ab_0    conda-forge
# argon2-cffi-bindings      25.1.0          py310hd2d5e8d_2    conda-forge
# arrow                     1.4.0              pyhcf101f3_0    conda-forge
# asttokens                 3.0.1              pyhd8ed1ab_0    conda-forge
# async-lru                 2.1.0              pyhcf101f3_0    conda-forge
# attrs                     25.3.0                   pypi_0    pypi
# babel                     2.17.0             pyhd8ed1ab_0    conda-forge
# beautifulsoup4            4.13.3                   pypi_0    pypi
# bleach                    6.3.0              pyhcf101f3_0    conda-forge
# bleach-with-css           6.3.0                h5f6438b_0    conda-forge
# blinker                   1.9.0                    pypi_0    pypi
# boltons                   23.1.1             pyhd8ed1ab_0    conda-forge
# branca                    0.8.1                    pypi_0    pypi
# brotli-python             1.1.0           py310h9e9d8ca_1    conda-forge
# bzip2                     1.0.8                h10d778d_5    conda-forge
# c-ares                    1.24.0               h10d778d_0    conda-forge
# ca-certificates           2026.1.4             hbd8a1cb_0    conda-forge
# cached-property           1.5.2                hd8ed1ab_1    conda-forge
# cached_property           1.5.2              pyha770c72_1    conda-forge
# cachetools                5.5.2                    pypi_0    pypi
# certifi                   2026.1.4           pyhd8ed1ab_0    conda-forge
# cffi                      1.16.0          py310hdca579f_0    conda-forge
# charset-normalizer        3.3.2              pyhd8ed1ab_0    conda-forge
# click                     8.1.8                    pypi_0    pypi
# click-plugins             1.1.1                    pypi_0    pypi
# cligj                     0.7.2                    pypi_0    pypi
# colorama                  0.4.6              pyhd8ed1ab_0    conda-forge
# comm                      0.2.3              pyhe01879c_0    conda-forge
# conda                     23.11.0         py310h2ec42d9_1    conda-forge
# conda-libmamba-solver     23.12.0            pyhd8ed1ab_0    conda-forge
# conda-package-handling    2.2.0              pyh38be061_0    conda-forge
# conda-package-streaming   0.9.0              pyhd8ed1ab_0    conda-forge
# contextily                1.6.2                    pypi_0    pypi
# contourpy                 1.3.1                    pypi_0    pypi
# curl-cffi                 0.13.0                   pypi_0    pypi
# cycler                    0.12.1                   pypi_0    pypi
# debugpy                   1.8.5           py310he0a0c5d_0    conda-forge
# decorator                 5.2.1              pyhd8ed1ab_0    conda-forge
# defusedxml                0.7.1              pyhd8ed1ab_0    conda-forge
# distro                    1.8.0              pyhd8ed1ab_0    conda-forge
# entrypoints               0.4                pyhd8ed1ab_1    conda-forge
# esda                      2.7.0                    pypi_0    pypi
# exceptiongroup            1.3.1              pyhd8ed1ab_0    conda-forge
# executing                 2.2.1              pyhd8ed1ab_0    conda-forge
# fiona                     1.10.1                   pypi_0    pypi
# fmt                       10.1.1               he51d815_1    conda-forge
# folium                    0.15.0                   pypi_0    pypi
# fonttools                 4.56.0                   pypi_0    pypi
# formulaic                 1.2.1                    pypi_0    pypi
# fqdn                      1.5.1              pyhd8ed1ab_1    conda-forge
# frozendict                2.4.7                    pypi_0    pypi
# geographiclib             2.0                      pypi_0    pypi
# geopandas                 0.14.1                   pypi_0    pypi
# geopy                     2.4.1                    pypi_0    pypi
# giddy                     2.3.6                    pypi_0    pypi
# gitdb                     4.0.12                   pypi_0    pypi
# gitpython                 3.1.44                   pypi_0    pypi
# greenlet                  3.3.1                    pypi_0    pypi
# h11                       0.16.0             pyhcf101f3_1    conda-forge
# h2                        4.3.0              pyhcf101f3_0    conda-forge
# hpack                     4.1.0              pyhd8ed1ab_0    conda-forge
# httpcore                  1.0.9              pyh29332c3_0    conda-forge
# httpx                     0.28.1             pyhd8ed1ab_0    conda-forge
# hyperframe                6.1.0              pyhd8ed1ab_0    conda-forge
# icu                       73.2                 hf5e326d_0    conda-forge
# idna                      3.6                pyhd8ed1ab_0    conda-forge
# immutabledict             4.3.1                    pypi_0    pypi
# importlib-metadata        7.2.1                    pypi_0    pypi
# importlib_resources       6.5.2              pyhd8ed1ab_0    conda-forge
# interface-meta            1.3.0                    pypi_0    pypi
# ipykernel                 6.29.5             pyh57ce528_0    conda-forge
# ipython                   8.37.0             pyh8f84b5b_0    conda-forge
# isoduration               20.11.0            pyhd8ed1ab_1    conda-forge
# jedi                      0.19.2             pyhd8ed1ab_1    conda-forge
# jinja2                    3.1.6              pyhcf101f3_1    conda-forge
# joblib                    1.4.2                    pypi_0    pypi
# json5                     0.13.0             pyhd8ed1ab_0    conda-forge
# jsonpatch                 1.33               pyhd8ed1ab_0    conda-forge
# jsonpointer               2.4             py310h2ec42d9_3    conda-forge
# jsonschema                4.23.0                   pypi_0    pypi
# jsonschema-specifications 2024.10.1                pypi_0    pypi
# jsonschema-with-format-nongpl 4.26.0               hcf101f3_0    conda-forge
# jupyter-lsp               2.3.0              pyhcf101f3_0    conda-forge
# jupyter_client            7.4.9              pyhd8ed1ab_0    conda-forge
# jupyter_core              5.9.1              pyhc90fa1f_0    conda-forge
# jupyter_events            0.12.0             pyh29332c3_0    conda-forge
# jupyter_server            2.17.0             pyhcf101f3_0    conda-forge
# jupyter_server_terminals  0.5.4              pyhcf101f3_0    conda-forge
# jupyterlab                4.5.3              pyhd8ed1ab_0    conda-forge
# jupyterlab_pygments       0.3.0              pyhd8ed1ab_2    conda-forge
# jupyterlab_server         2.28.0             pyhcf101f3_0    conda-forge
# jupytext                  1.19.1                   pypi_0    pypi
# kiwisolver                1.4.8                    pypi_0    pypi
# krb5                      1.21.2               hb884880_0    conda-forge
# lark                      1.3.1              pyhd8ed1ab_0    conda-forge
# libarchive                3.7.2                hd35d340_1    conda-forge
# libcurl                   8.5.0                h726d00d_0    conda-forge
# libcxx                    16.0.6               hd57cbcb_0    conda-forge
# libedit                   3.1.20191231         h0678c8f_2    conda-forge
# libev                     4.33                 h10d778d_2    conda-forge
# libffi                    3.4.2                h0d85af4_5    conda-forge
# libiconv                  1.17                 hd75f5a5_2    conda-forge
# libmamba                  1.5.5                hb976dfd_0    conda-forge
# libmambapy                1.5.5           py310hd068509_0    conda-forge
# libnghttp2                1.58.0               h64cf6d3_1    conda-forge
# libpysal                  4.12.1                   pypi_0    pypi
# libsodium                 1.0.18               hbcb3906_1    conda-forge
# libsolv                   0.7.27               hf4d7fad_0    conda-forge
# libsqlite                 3.44.2               h92b6c6a_0    conda-forge
# libssh2                   1.11.0               hd019ec5_0    conda-forge
# libxml2                   2.12.3               hc0ae0f7_0    conda-forge
# libzlib                   1.2.13               h8a1eda9_5    conda-forge
# linearmodels              7.0                      pypi_0    pypi
# llvmlite                  0.44.0                   pypi_0    pypi
# lxml                      6.0.2                    pypi_0    pypi
# lz4-c                     1.9.4                hf0c8a7f_0    conda-forge
# lzo                       2.10              haf1e3a3_1000    conda-forge
# mamba                     1.5.5           py310h6bde348_0    conda-forge
# mapclassify               2.8.1                    pypi_0    pypi
# markdown-it-py            3.0.0                    pypi_0    pypi
# markupsafe                3.0.2                    pypi_0    pypi
# matplotlib                3.8.2                    pypi_0    pypi
# matplotlib-inline         0.2.1              pyhd8ed1ab_0    conda-forge
# mdit-py-plugins           0.5.0                    pypi_0    pypi
# mdurl                     0.1.2                    pypi_0    pypi
# menuinst                  2.0.1           py310h2ec42d9_0    conda-forge
# mercantile                1.2.1                    pypi_0    pypi
# mistune                   3.2.0              pyhcf101f3_0    conda-forge
# mpmath                    1.3.0                    pypi_0    pypi
# multitasking              0.0.12                   pypi_0    pypi
# mypy-extensions           1.1.0                    pypi_0    pypi
# narwhals                  1.31.0                   pypi_0    pypi
# nbclient                  0.10.4             pyhd8ed1ab_0    conda-forge
# nbconvert-core            7.16.6             pyhcf101f3_1    conda-forge
# nbformat                  5.10.4             pyhd8ed1ab_1    conda-forge
# ncurses                   6.4                  h93d8f39_2    conda-forge
# nest-asyncio              1.6.0              pyhd8ed1ab_1    conda-forge
# networkx                  3.4.2                    pypi_0    pypi
# notebook                  7.5.3              pyhcf101f3_0    conda-forge
# notebook-shim             0.2.4              pyhd8ed1ab_1    conda-forge
# numba                     0.61.0                   pypi_0    pypi
# numpy                     1.26.4                   pypi_0    pypi
# openssl                   3.6.1                hb6871ef_1    conda-forge
# ortools                   9.15.6755                pypi_0    pypi
# overrides                 7.7.0              pyhd8ed1ab_1    conda-forge
# packaging                 23.2               pyhd8ed1ab_0    conda-forge
# pandas                    2.3.3                    pypi_0    pypi
# pandas-datareader         0.10.0                   pypi_0    pypi
# pandocfilters             1.5.0              pyhd8ed1ab_0    conda-forge
# parso                     0.8.5              pyhcf101f3_0    conda-forge
# patsy                     1.0.1                    pypi_0    pypi
# peewee                    3.19.0                   pypi_0    pypi
# pexpect                   4.9.0              pyhd8ed1ab_1    conda-forge
# pickleshare               0.7.5           pyhd8ed1ab_1004    conda-forge
# pillow                    10.4.0                   pypi_0    pypi
# pip                       23.3.2             pyhd8ed1ab_0    conda-forge
# platformdirs              4.1.0              pyhd8ed1ab_0    conda-forge
# playwright                1.57.0                   pypi_0    pypi
# plotly                    6.0.1                    pypi_0    pypi
# pluggy                    1.3.0              pyhd8ed1ab_0    conda-forge
# prometheus_client         0.24.1             pyhd8ed1ab_0    conda-forge
# prompt-toolkit            3.0.52             pyha770c72_0    conda-forge
# protobuf                  6.33.5                   pypi_0    pypi
# psutil                    7.2.1           py310h8bcfd8d_0    conda-forge
# ptyprocess                0.7.0              pyhd8ed1ab_1    conda-forge
# pure_eval                 0.2.3              pyhd8ed1ab_1    conda-forge
# pyarrow                   19.0.1                   pypi_0    pypi
# pybind11-abi              4                    hd8ed1ab_3    conda-forge
# pycosat                   0.6.6           py310h6729b98_0    conda-forge
# pycparser                 2.21               pyhd8ed1ab_0    conda-forge
# pydeck                    0.9.1                    pypi_0    pypi
# pyee                      13.0.0                   pypi_0    pypi
# pygments                  2.19.1                   pypi_0    pypi
# pyhdfe                    0.2.0                    pypi_0    pypi
# pyobjc-core               11.0            py310hae5a141_0    conda-forge
# pyobjc-framework-cocoa    11.0            py310hae5a141_0    conda-forge
# pyogrio                   0.10.0                   pypi_0    pypi
# pyparsing                 3.2.1                    pypi_0    pypi
# pypdf                     5.7.0                    pypi_0    pypi
# pyproj                    3.7.1                    pypi_0    pypi
# pysocks                   1.7.1              pyha2e5f31_6    conda-forge
# python                    3.10.13         h00d2728_0_cpython    conda-forge
# python-dateutil           2.9.0.post0        pyhe01879c_2    conda-forge
# python-fastjsonschema     2.21.2             pyhe01879c_0    conda-forge
# python-json-logger        2.0.7              pyhd8ed1ab_0    conda-forge
# python-tzdata             2025.3             pyhd8ed1ab_0    conda-forge
# python_abi                3.10                    4_cp310    conda-forge
# pytz                      2025.1                   pypi_0    pypi
# pyyaml                    6.0.3           py310hd951482_0    conda-forge
# pyzmq                     24.0.1          py310hf615a82_1    conda-forge
# quantecon                 0.8.0                    pypi_0    pypi
# quantecon-book-networks   1.5                      pypi_0    pypi
# rasterio                  1.4.3                    pypi_0    pypi
# readline                  8.2                  h9e318b2_1    conda-forge
# referencing               0.36.2                   pypi_0    pypi
# reproc                    14.2.4.post0         h10d778d_1    conda-forge
# reproc-cpp                14.2.4.post0         h93d8f39_1    conda-forge
# requests                  2.31.0             pyhd8ed1ab_0    conda-forge
# rfc3339-validator         0.1.4              pyhd8ed1ab_1    conda-forge
# rfc3986-validator         0.1.1              pyh9f0ad1d_0    conda-forge
# rfc3987-syntax            1.1.0              pyhe01879c_1    conda-forge
# rich                      13.9.4                   pypi_0    pypi
# rpds-py                   0.23.1                   pypi_0    pypi
# ruamel.yaml               0.18.5          py310hb372a2b_0    conda-forge
# ruamel.yaml.clib          0.2.7           py310h6729b98_2    conda-forge
# scikit-learn              1.6.1                    pypi_0    pypi
# scipy                     1.15.2                   pypi_0    pypi
# seaborn                   0.13.2                   pypi_0    pypi
# send2trash                2.1.0              pyh5552912_0    conda-forge
# setuptools                68.2.2             pyhd8ed1ab_0    conda-forge
# shapely                   2.0.7                    pypi_0    pypi
# six                       1.17.0             pyhe01879c_1    conda-forge
# smmap                     5.0.2                    pypi_0    pypi
# sniffio                   1.3.1              pyhd8ed1ab_2    conda-forge
# soupsieve                 2.6                      pypi_0    pypi
# splot                     1.1.7                    pypi_0    pypi
# spreg                     1.8.2                    pypi_0    pypi
# stack_data                0.6.3              pyhd8ed1ab_1    conda-forge
# statsmodels               0.14.4                   pypi_0    pypi
# streamlit                 1.31.0                   pypi_0    pypi
# streamlit-folium          0.15.0                   pypi_0    pypi
# sympy                     1.13.3                   pypi_0    pypi
# tabulate                  0.9.0                    pypi_0    pypi
# tenacity                  8.5.0                    pypi_0    pypi
# terminado                 0.18.1             pyhc90fa1f_1    conda-forge
# threadpoolctl             3.6.0                    pypi_0    pypi
# tinycss2                  1.4.0                    pypi_0    pypi
# tk                        8.6.13               h1abcd95_1    conda-forge
# toml                      0.10.2                   pypi_0    pypi
# tomli                     2.4.0              pyhcf101f3_0    conda-forge
# tornado                   6.4.2                    pypi_0    pypi
#
# traitlets                 5.14.3             pyhd8ed1ab_1    conda-forge
# truststore                0.8.0              pyhd8ed1ab_0    conda-forge
# typing-extensions         4.12.2                   pypi_0    pypi
# typing_extensions         4.15.0             pyhcf101f3_0    conda-forge
# typing_utils              0.1.0              pyhd8ed1ab_1    conda-forge
# tzdata                    2025.1                   pypi_0    pypi
# tzlocal                   5.3.1                    pypi_0    pypi
# uri-template              1.3.0              pyhd8ed1ab_1    conda-forge
# urllib3                   2.1.0              pyhd8ed1ab_0    conda-forge
# validators                0.34.0                   pypi_0    pypi
# vega-datasets             0.9.0                    pypi_0    pypi
# watchdog                  6.0.0                    pypi_0    pypi
# wbgapi                    1.0.12                   pypi_0    pypi
# wcwidth                   0.2.14             pyhd8ed1ab_0    conda-forge
# webcolors                 25.10.0            pyhd8ed1ab_0    conda-forge
# webencodings              0.5.1              pyhd8ed1ab_3    conda-forge
# websocket-client          1.9.0              pyhd8ed1ab_0    conda-forge
# websockets                16.0                     pypi_0    pypi
# wheel                     0.42.0             pyhd8ed1ab_0    conda-forge
# wrapt                     2.0.1                    pypi_0    pypi
# xgboost                   3.1.3                    pypi_0    pypi
# xlrd                      2.0.2                    pypi_0    pypi
# xyzservices               2025.1.0                 pypi_0    pypi
# xz                        5.2.6                h775f41a_0    conda-forge
# yaml                      0.2.5                h4132b18_3    conda-forge
# yaml-cpp                  0.8.0                he965462_0    conda-forge
# yfinance                  1.2.0                    pypi_0    pypi
# zeromq                    4.3.5                hde137ed_4    conda-forge
# zipp                      3.21.0                   pypi_0    pypi
# zstandard                 0.22.0          py310hd88f66e_0    conda-forge
# zstd                      1.5.5                h829000d_0    conda-forge
